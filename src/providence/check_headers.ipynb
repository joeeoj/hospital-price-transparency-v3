# %%
from collections import namedtuple
from pathlib import Path, PosixPath

import pandas as pd

from src import COMPLETED

# %%
CURRENT_DIR = Path().cwd()

# %%
def parse_cms_from_fname(fname: PosixPath) -> str:
    s = fname.name.split('_')[0] if '_' in fname.name else fname.name.split('-')[0]
    return s.replace('~$', '')

def parse_location(fname: PosixPath) -> str:
    s = fname.name.split('_')[1] if '_' in fname.name else fname.name.split('-')[1]
    for v in ['providenceregionalmedicalcenter', 'regionalmedicalcenter', 'providence', 'medicalcenter']:
        s = s.replace(v, '')
    return s

def add_prices(prices: pd.Series) -> float:
    """Convert to cents, sum, then convert back to float"""
    cents = [0 if pd.isnull(p) else int(p) * 100 for p in prices]
    return sum(cents)/100.0

# %%
File = namedtuple('File', ['fname', 'cms', 'location'])

files = []
for f in CURRENT_DIR.glob('*.xlsx'):
    files.append(File(f.name, parse_cms_from_fname(f), parse_location(f)))

files
# Out:
# [File(fname='501326_providencemountcarmel_standardcharges.xlsx', cms='501326', location='mountcarmel'),
#  File(fname='500014_providenceregionalmedicalcentereverett_standardcharges.xlsx', cms='500014', location='everett'),
#  File(fname='500002_providencestmarymedicalcenter_standardcharges.xlsx', cms='500002', location='stmary'),
#  File(fname='500054_providencesacredheartmedicalcenter_standardcharges.xlsx', cms='500054', location='sacredheart'),
#  File(fname='501309_providencestjosephmedicalcenterofchewelah_standardcharges.xlsx', cms='501309', location='stjosephofchewelah'),
#  File(fname='500024_providencestpeterhospital_standardcharges.xlsx', cms='500024', location='stpeterhospital'),
#  File(fname='500019_providencecentraliahospital_standardcharges.xlsx', cms='500019', location='centraliahospital'),
#  File(fname='500077_providenceholyfamilyhospital_standardcharges.xlsx', cms='500077', location='holyfamilyhospital'),
#  File(fname='500058-kadlecregionalmedicalcenter-standardcharges.xlsx', cms='500058', location='kadlec')]

# %%
for f in files:
    a = pd.read_excel(f.fname, sheet_name='Gross Charges', skiprows=[0,1,2,3])
    b = pd.read_excel(f.fname, sheet_name='Discount Cash Price - Gross', skiprows=[0,1,2,3])

    print(f.fname)
    print(a.columns)
    print(b.columns)
    print('-' * 80)
# Out:
# 501326_providencemountcarmel_standardcharges.xlsx
# Index(['HOSPITAL SYSTEM CHARGE CODE', 'CHARGE DESCRIPTION',
#        'CPT(R)/HCPCS Code', 'WMC LOCATION (Unit Price) [IP/OP]',
#        'WMC LOCATION (Base Price) [IP/OP]',
#        'WMC LABOR AND DELIVERY (37074000) [IP/OP]',
#        'WMC DIAGNOSTIC IMAGING (37076300) [IP/OP]',
#        'WMC SURGERY CLINIC (37070780) [IP/OP]',
#        'WMC EMERGENCY PHYSICIANS (37070101) [IP/OP]',
#        'WMC AMBULATORY SURGERY SERVICES (37074300) [OP]',
#        'WMC EMERGENCY SERVICES (37070100) [IP/OP]',
#        'WMC INTENSIVE CARE UNIT (37060100) [IP]',
#        'WMC IV THERAPY (37077150) [IP/OP]',
#        'WMC RESPIRATORY THERAPY (37077200) [IP/OP]',
#        'WMC CARDIOLOGY SERVICES (37075900) [OP]'],
#       dtype='object')
# Index(['HOSPITAL SYSTEM CHARGE CODE', 'CHARGE DESCRIPTION',
#        'CPT(R)/HCPCS Code',
#        'WMC LOCATION (Unit Price) [IP/OP] DISCOUNT CASH PRICE',
#        'WMC LOCATION (Base Price) [IP/OP] DISCOUNT CASH PRICE',
#        'WMC LABOR AND DELIVERY (37074000) [IP/OP] DISCOUNT CASH PRICE',
#        'WMC DIAGNOSTIC IMAGING (37076300) [IP/OP] DISCOUNT CASH PRICE',
#        'WMC SURGERY CLINIC (37070780) [IP/OP] DISCOUNT CASH PRICE',
#        'WMC EMERGENCY PHYSICIANS (37070101) [IP/OP] DISCOUNT CASH PRICE',
#        'WMC AMBULATORY SURGERY SERVICES (37074300) [OP] DISCOUNT CASH PRICE',
#        'WMC EMERGENCY SERVICES (37070100) [IP/OP] DISCOUNT CASH PRICE',
#        'WMC INTENSIVE CARE UNIT (37060100) [IP] DISCOUNT CASH PRICE',
#        'WMC IV THERAPY (37077150) [IP/OP] DISCOUNT CASH PRICE',
#        'WMC RESPIRATORY THERAPY (37077200) [IP/OP] DISCOUNT CASH PRICE',
#        'WMC CARDIOLOGY SERVICES (37075900) [OP] DISCOUNT CASH PRICE'],
#       dtype='object')
# --------------------------------------------------------------------------------
# 500014_providenceregionalmedicalcentereverett_standardcharges.xlsx
# Index(['HOSPITAL SYSTEM CHARGE CODE', 'CHARGE DESCRIPTION', 'CPT/HCPCS CODE',
#        'WEV LOCATION (Unit Price) [IP/OP]',
#        'WEV LOCATION (Base Price) [IP/OP]'],
#       dtype='object')
# Index(['HOSPITAL SYSTEM CHARGE CODE', 'CHARGE DESCRIPTION', 'CPT/HCPCS CODE',
#        'WEV LOCATION (Unit Price) [IP/OP] DISCOUNT CASH PRICE',
#        'WEV LOCATION (Base Price) [IP/OP] DISCOUNT CASH PRICE'],
#       dtype='object')
# --------------------------------------------------------------------------------
# 500002_providencestmarymedicalcenter_standardcharges.xlsx
# Index(['HOSPITAL SYSTEM CHARGE CODE', 'CHARGE DESCRIPTION',
#        'CPT(R)/HCPCS Code', 'WSM LOCATION (Unit Price) [IP/OP]',
#        'WSM LOCATION (Base Price) [IP/OP]', 'WSM OUTPATIENT [OP]',
#        'WSM IP REHAB (32564400) [IP]'],
#       dtype='object')
# Index(['HOSPITAL SYSTEM CHARGE CODE', 'CHARGE DESCRIPTION',
#        'CPT(R)/HCPCS Code',
#        'WSM LOCATION (Unit Price) [IP/OP] DISCOUNT CASH PRICE',
#        'WSM LOCATION (Base Price) [IP/OP] DISCOUNT CASH PRICE',
#        'WSM OUTPATIENT [OP] DISCOUNT CASH PRICE',
#        'WSM IP REHAB (32564400) [IP] DISCOUNT CASH PRICE'],
#       dtype='object')
# --------------------------------------------------------------------------------
# 500054_providencesacredheartmedicalcenter_standardcharges.xlsx
# Index(['HOSPITAL SYSTEM CHARGE CODE', 'CHARGE DESCRIPTION', 'CPT/HCPCS CODE',
#        'WSH LOCATION  (Unit Price) [IP/OP]',
#        'WSH LOCATION (Base Price) [IP/OP]', 'WSH OUTPATIENT [OP]'],
#       dtype='object')
# Index(['HOSPITAL SYSTEM CHARGE CODE', 'CHARGE DESCRIPTION', 'CPT/HCPCS CODE',
#        'WSH LOCATION  (Unit Price) [IP/OP] DISCOUNT CASH PRICE',
#        'WSH LOCATION (Base Price) [IP/OP] DISCOUNT CASH PRICE',
#        'WSH OUTPATIENT [OP] DISCOUNT CASH PRICE'],
#       dtype='object')
# --------------------------------------------------------------------------------
# 501309_providencestjosephmedicalcenterofchewelah_standardcharges.xlsx
# Index(['HOSPITAL SYSTEM CHARGE CODE', 'CHARGE DESCRIPTION',
#        'CPT(R)/HCPCS Code', 'WSJ LOCATION (Unit Price) [IP/OP]',
#        'WSJ LOCATION (Base Price) [IP/OP]',
#        'WSJ EMERGENCY SERVICES (37570100) [IP/OP]',
#        'WSJ SURGERY CLINIC (37570780) [IP/OP]',
#        'WSJ EMERGENCY PHYSICIANS (37570101) [IP/OP]',
#        'WSJ RESPIRATORY THERAPY (37577200) [IP/OP]',
#        'WSJ MEDICAL ACUTE (37561710) [IP/OP]',
#        'WSJ SURGICAL SERVICES (37574200) [IP/OP]',
#        'WSJ IV THERAPY (37577150) [IP/OP]'],
#       dtype='object')
# Index(['HOSPITAL SYSTEM CHARGE CODE', 'CHARGE DESCRIPTION',
#        'CPT(R)/HCPCS Code',
#        'WSJ LOCATION (Unit Price) [IP/OP] DISCOUNT CASH PRICE',
#        'WSJ LOCATION (Base Price) [IP/OP] DISCOUNT CASH PRICE',
#        'WSJ EMERGENCY SERVICES (37570100) [IP/OP] DISCOUNT CASH PRICE',
#        'WSJ SURGERY CLINIC (37570780) [IP/OP] DISCOUNT CASH PRICE',
#        'WSJ EMERGENCY PHYSICIANS (37570101) [IP/OP] DISCOUNT CASH PRICE',
#        'WSJ RESPIRATORY THERAPY (37577200) [IP/OP] DISCOUNT CASH PRICE',
#        'WSJ MEDICAL ACUTE (37561710) [IP/OP] DISCOUNT CASH PRICE',
#        'WSJ SURGICAL SERVICES (37574200) [IP/OP] DISCOUNT CASH PRICE',
#        'WSJ IV THERAPY (37577150) [IP/OP] DISCOUNT CASH PRICE'],
#       dtype='object')
# --------------------------------------------------------------------------------
# 500024_providencestpeterhospital_standardcharges.xlsx
# Index(['HOSPITAL SYSTEM CHARGE CODE', 'CHARGE DESCRIPTION', 'CPT/HCPCS CODE',
#        'WSP LOCATION (Unit Price) [IP/OP]',
#        'WSP LOCATION (Base Price) [IP/OP]'],
#       dtype='object')
# Index(['HOSPITAL SYSTEM CHARGE CODE', 'CHARGE DESCRIPTION', 'CPT/HCPCS CODE',
#        'WSP LOCATION (Unit Price) [IP/OP] DISCOUNT CASH PRICE',
#        'WSP LOCATION (Base Price) [IP/OP] DISCOUNT CASH PRICE'],
#       dtype='object')
# --------------------------------------------------------------------------------
# 500019_providencecentraliahospital_standardcharges.xlsx
# Index(['HOSPITAL SYSTEM CHARGE CODE', 'CHARGE DESCRIPTION', 'CPT/HCPCS CODE',
#        'WCH LOCATION (Unit Price) [IP/OP]',
#        'WCH LOCATION (Base Price) [IP/OP]'],
#       dtype='object')
# Index(['HOSPITAL SYSTEM CHARGE CODE', 'CHARGE DESCRIPTION', 'CPT/HCPCS CODE',
#        'WCH LOCATION (Unit Price) [IP/OP] DISCOUNT CASH PRICE',
#        'WCH LOCATION (Base Price) [IP/OP] DISCOUNT CASH PRICE'],
#       dtype='object')
# --------------------------------------------------------------------------------
# 500077_providenceholyfamilyhospital_standardcharges.xlsx
# Index(['HOSPITAL SYSTEM CHARGE CODE', 'CHARGE DESCRIPTION', 'CPT/HCPCS CODE',
#        'WHF LOCATION (Unit Price) [IP/OP]',
#        'WHF LOCATION (Base Price) [IP/OP]', 'WHF OUTPATIENT [OP]'],
#       dtype='object')
# Index(['HOSPITAL SYSTEM CHARGE CODE', 'CHARGE DESCRIPTION', 'CPT/HCPCS CODE',
#        'WHF LOCATION (Unit Price) [IP/OP] DISCOUNT CASH PRICE',
#        'WHF LOCATION (Base Price) [IP/OP] DISCOUNT CASH PRICE',
#        'WHF OUTPATIENT [OP] DISCOUNT CASH PRICE'],
#       dtype='object')
# --------------------------------------------------------------------------------
# 500058-kadlecregionalmedicalcenter-standardcharges.xlsx
# Index(['CDM Code', 'Description', 'CPT(R)/HCPCS Code',
#        'KMC LOCATION (Unit Price) [IP/OP]',
#        'KMC LOCATION (Base Price) [IP/OP]', 'KMC OUTPATIENT [OP]'],
#       dtype='object')
# Index(['CDM Code', 'Description', 'CPT(R)/HCPCS Code',
#        'KMC LOCATION (Unit Price) [IP/OP] DISCOUNT CASH PRICE',
#        'KMC LOCATION (Base Price) [IP/OP] DISCOUNT CASH PRICE',
#        'KMC OUTPATIENT [OP] DISCOUNT CASH PRICE'],
#       dtype='object')
# --------------------------------------------------------------------------------
